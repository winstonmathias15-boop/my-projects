# %% [markdown]
# <a href="https://colab.research.google.com/github/winstonmathias15-boop/my-projects/blob/master/agecheck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def is_adult():
  age = int(input("How old are you?: ")) # Convert input to integer
  if age > 18:
    return "You are an adult"
  else:
    return "You are still a Minor"

new_call=is_adult()
print(new_call)
# Out:
# How old are you?: 16
# You are still a Minor
